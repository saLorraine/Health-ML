# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/powermac'

# %%
path = '/Users/powermac'+ 'Desktop/MCH.csv'

# %% [markdown]
# # LOAD DATA

# %%
import pandas as pd

# %%
Maternal_df = pd.read_csv('MCH.csv')

# %%
Maternal_df.head()
# Out:
#    client_id        patient_nupn date_of_birth sex  \
# 0     924475  5001-00140-02257-6    2000-11-09   F
# 1    6381233  3002-00680-05175-8    1978-01-15   F
# 2   14669129    76896F0F-1E37-46    1981-08-21   F
# 3   16793041    3030-010-52317-8    1997-08-30   F
# 4   17500540    3030-010-69153-4    1978-07-06   F
#
#                   facility_name province             service interaction_date  \
# 0        Mwembeshi Rural Health   Lusaka  Delivery Discharge       2020-02-25
# 1  Namseche Urban Health Center  Eastern  Delivery Discharge       2019-01-04
# 2    Pollen Urban Health Center  Central  Delivery Discharge       2021-03-19
# 3      Chipata Central Hospital  Eastern  Delivery Discharge       2015-05-16
# 4      Chipata Central Hospital  Eastern  Delivery Discharge       2017-03-21
#
#   in_patient_register_number maternal_death_after_delivery  ... pallor  \
# 0                        NaN                         False  ...    NaN
# ...

# %%
Maternal_df.tail()
# Out:
#        client_id      patient_nupn date_of_birth sex           facility_name  \
# 25663   64241445  8070-133-10047-2    1993-02-01   F  Nansenga Health Center
# 25664   64241445  8070-133-10047-2    1993-02-01   F  Nansenga Health Center
# 25665   64278153  8070-13Y-00119-1    1989-11-01   F  Nansenga Health Center
# 25666   64319535  5020-260-05071-3    1992-12-27   F  Nansenga Health Center
# 25667   64346616  8070-133-01021-4    1983-10-23   F  Nansenga Health Center
#
#        province             service interaction_date  \
# 25663  Southern  Delivery Discharge       2016-06-06
# 25664  Southern  Delivery Discharge       2019-01-14
# 25665  Southern  Delivery Discharge       2016-08-02
# 25666  Southern  Delivery Discharge       2017-12-04
# 25667  Southern  Delivery Discharge       2019-03-14
#
#       in_patient_register_number maternal_death_after_delivery  ... pallor  \
# 25663                        NaN                         False  ...    NaN
# ...

# %%
Maternal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25668 entries, 0 to 25667
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   client_id                                   25668 non-null  int64
#  1   patient_nupn                                25668 non-null  object
#  2   date_of_birth                               25668 non-null  object
#  3   sex                                         25668 non-null  object
#  4   facility_name                               25668 non-null  object
#  5   province                                    25668 non-null  object
#  6   service                                     25668 non-null  object
#  7   interaction_date                            25668 non-null  object
#  8   in_patient_register_number                  13040 non-null  object
#  9   maternal_death_after_delivery               24832 non-null  object
# ...

# %%
Maternal_df.isnull().sum()
# Out:
# client_id                                         0
# patient_nupn                                      0
# date_of_birth                                     0
# sex                                               0
# facility_name                                     0
# province                                          0
# service                                           0
# interaction_date                                  0
# in_patient_register_number                    12628
# maternal_death_after_delivery                   836
# postnatal_visit_date                          11463
# delivery_discharge_new_born_details_uuid       5132
# under5_card_given                              6215
# breast_fed_in_one_hour                         6626
# breastfeeding_well                             6563
# feeding_methods                                6226
# delivery_discharge_new_born_treatment_uuid    17923
# bcg_given                                     18901
# ...

# %%
Maternal_df.describe()
# Out:
#           client_id  disp_duration  test_date  test_result   pulse_rate  \
# count  2.566800e+04     476.000000        0.0          0.0  2939.000000
# mean   2.267587e+07      62.352941        NaN          NaN    87.529432
# std    9.333033e+06      48.445753        NaN          NaN   178.837457
# min    6.443980e+05       0.000000        NaN          NaN     0.000000
# 25%    1.892540e+07      30.000000        NaN          NaN    76.000000
# 50%    2.279102e+07      60.000000        NaN          NaN    82.000000
# 75%    2.642934e+07      90.000000        NaN          NaN    92.000000
# max    8.063342e+07     180.000000        NaN          NaN  9736.000000
#
#          itn_used  temperature  systolic_blood_pressure  \
# count  176.000000  2883.000000              3200.000000
# mean     0.954545    39.575317               127.840000
# std      0.208893    97.671001               335.970096
# min      0.000000     0.000000                11.000000
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
# Handling Missing values

# %% [markdown]
# # drop columns.

# %%
Maternal_df['maternal_death_after_delivery'].fillna(Maternal_df['maternal_death_after_delivery'].mode(), inplace=True)
Maternal_df['date_of_birth'].fillna(Maternal_df['date_of_birth'].mode(), inplace=True)
Maternal_df['delivery_discharge_new_born_treatment_uuid'].fillna(Maternal_df['delivery_discharge_new_born_treatment_uuid'].mode(), inplace=True)
Maternal_df['temperature'].fillna(Maternal_df['temperature'].mean(), inplace=True)

Maternal_df['systolic_blood_pressure'].fillna(Maternal_df['systolic_blood_pressure'].mean(), inplace=True)
Maternal_df['diastolic_blood_pressure'].fillna(Maternal_df['diastolic_blood_pressure'].mean(), inplace=True)
Maternal_df['test_result'].fillna(Maternal_df['test_result'].mean(), inplace=True)
Maternal_df['sex'].fillna(Maternal_df['sex'].mode(), inplace=True)
Maternal_df['new_born_pmtct_dosage'].fillna(Maternal_df['new_born_pmtct_dosage'].mode(), inplace=True)
Maternal_df['doses'].fillna(Maternal_df['doses'].mode(), inplace=True)
Maternal_df['screened_for_tb'].fillna(Maternal_df['screened_for_tb'].mode(), inplace=True)
Maternal_df['other_immunizations'].fillna(Maternal_df['other_immunizations'].mode(), inplace=True)
Maternal_df['safe_motherhood_number'].fillna(Maternal_df['safe_motherhood_number'].mode(), inplace=True)
Maternal_df['pallor'].fillna(Maternal_df['pallor'].mode(), inplace=True)
Maternal_df['lochia'].fillna(Maternal_df['lochia'].mode(), inplace=True)
Maternal_df['urine_glucose'].fillna(Maternal_df['urine_glucose'].mode(), inplace=True)
Maternal_df['uterus_contracted'].fillna(Maternal_df['uterus_contracted'].mode(), inplace=True)
Maternal_df['feeding_methods'].fillna(Maternal_df['feeding_methods'].mode(), inplace=True)
Maternal_df['art_number'].fillna(Maternal_df['art_number'].mode(), inplace=True)
Maternal_df['baby_received_arv_within_72_hours'].fillna(Maternal_df['baby_received_arv_within_72_hours'].mode(), inplace=True)
Maternal_df['under5_card_given'].fillna(Maternal_df['under5_card_given'].mode(), inplace=True)
Maternal_df['breast_fed_in_one_hour'].fillna(Maternal_df['breast_fed_in_one_hour'].mode(), inplace=True)
Maternal_df['vitamin_a_supplement'].fillna(Maternal_df['vitamin_a_supplement'].mode(), inplace=True)
Maternal_df['bcg_given'].fillna(Maternal_df['bcg_given'].mode(), inplace=True)
Maternal_df['mother_uuid'].fillna(Maternal_df['mother_uuid'].mode(), inplace=True)
Maternal_df['breastfeeding_well'].fillna(Maternal_df['breastfeeding_well'].mode(), inplace=True)
Maternal_df['pulse_rate'].fillna(Maternal_df['pulse_rate'].mode(), inplace=True)
Maternal_df['feeding_options_incl_mixed'].fillna(Maternal_df['feeding_options_incl_mixed'].mode(), inplace=True)
Maternal_df['baby_uuid'].fillna(Maternal_df['baby_uuid'].mode(), inplace=True)
Maternal_df['mother_uuid'].fillna(Maternal_df['mother_uuid'].mode(), inplace=True)
Maternal_df['itn_used'].fillna(Maternal_df['itn_used'].mode(), inplace=True)
Maternal_df['pallor_type'].fillna(Maternal_df['pallor_type'].mode(), inplace=True)
Maternal_df['ctx_first_dose'].fillna(Maternal_df['ctx_first_dose'].mode(), inplace=True)

# %%
Maternal_df.head()
# Out:
#    client_id        patient_nupn date_of_birth sex  \
# 0     924475  5001-00140-02257-6    2000-11-09   F
# 1    6381233  3002-00680-05175-8    1978-01-15   F
# 2   14669129    76896F0F-1E37-46    1981-08-21   F
# 3   16793041    3030-010-52317-8    1997-08-30   F
# 4   17500540    3030-010-69153-4    1978-07-06   F
#
#                   facility_name province             service interaction_date  \
# 0        Mwembeshi Rural Health   Lusaka  Delivery Discharge       2020-02-25
# 1  Namseche Urban Health Center  Eastern  Delivery Discharge       2019-01-04
# 2    Pollen Urban Health Center  Central  Delivery Discharge       2021-03-19
# 3      Chipata Central Hospital  Eastern  Delivery Discharge       2015-05-16
# 4      Chipata Central Hospital  Eastern  Delivery Discharge       2017-03-21
#
#   in_patient_register_number maternal_death_after_delivery  ... pallor  \
# 0                        NaN                         False  ...  False
# ...

# %% [markdown]
# # visualisation

# %%
# Categorical Variables

# %%
sns.countplot(Maternal_df['maternal_death_after_delivery'])
# Out:
# <AxesSubplot:xlabel='maternal_death_after_delivery', ylabel='count'>

# %%
sns.countplot(Maternal_df['child_number'])
# Out:
# <AxesSubplot:xlabel='child_number', ylabel='count'>

# %%
sns.countplot(Maternal_df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(20,20))
sns.countplot(Maternal_df['ingredients'])
# Out:
# <AxesSubplot:xlabel='ingredients', ylabel='count'>

# %%
sns.countplot(Maternal_df['province'])
# Out:
# <AxesSubplot:xlabel='province', ylabel='count'>

# %%
sns.displot(Maternal_df['service'])

# %%
sns.countplot(Maternal_df['new_born_pmtct_dosage'])
# Out:
# <AxesSubplot:xlabel='new_born_pmtct_dosage', ylabel='count'>

# %%
plt.figure(figsize=(15,9))
sns.countplot(Maternal_df['doses'])
# Out:
# <AxesSubplot:xlabel='doses', ylabel='count'>

# %%
sns.countplot(Maternal_df['screened_for_tb'])
# Out:
# <AxesSubplot:xlabel='screened_for_tb', ylabel='count'>

# %%
sns.countplot(Maternal_df['other_immunizations'])
# Out:
# <AxesSubplot:xlabel='other_immunizations', ylabel='count'>

# %%
sns.displot(Maternal_df['art_number'])

# %%
sns.displot(Maternal_df['baby_received_arv_within_72_hours'])

# %%
sns.countplot(Maternal_df['uterus_contracted'])
# Out:
# <AxesSubplot:xlabel='uterus_contracted', ylabel='count'>

# %%
plt.figure(figsize=(9,6))
sns.histplot(Maternal_df['feeding_methods'])
# Out:
# <AxesSubplot:xlabel='feeding_methods', ylabel='Count'>

# %%
sns.countplot(Maternal_df['breastfeeding_well'])
# Out:
# <AxesSubplot:xlabel='breastfeeding_well', ylabel='count'>

# %%
sns.countplot(Maternal_df['breast_fed_in_one_hour'])
# Out:
# <AxesSubplot:xlabel='breast_fed_in_one_hour', ylabel='count'>

# %%
sns.histplot(Maternal_df['feeding_options_incl_mixed'])
# Out:
# <AxesSubplot:xlabel='feeding_options_incl_mixed', ylabel='Count'>

# %%
sns.countplot(Maternal_df['under5_card_given'])
# Out:
# <AxesSubplot:xlabel='under5_card_given', ylabel='count'>

# %%
sns.countplot(Maternal_df['vitamin_a_supplement'])
# Out:
# <AxesSubplot:xlabel='vitamin_a_supplement', ylabel='count'>

# %%
sns.countplot(Maternal_df['bcg_given'])
# Out:
# <AxesSubplot:xlabel='bcg_given', ylabel='count'>

# %%
sns.countplot(Maternal_df['pallor'])
# Out:
# <AxesSubplot:xlabel='pallor', ylabel='count'>

# %%
sns.countplot(Maternal_df['pallor_type'])
# Out:
# <AxesSubplot:xlabel='pallor_type', ylabel='count'>

# %%
sns.displot(Maternal_df['ctx_first_dose'])

# %%
# NUMERICAL VARIABLES

# %%
sns.displot(Maternal_df['temperature'])

# %%
sns.displot(Maternal_df['systolic_blood_pressure'])

# %%
Maternal_df['systolic_blood_pressure']=np.log(Maternal_df['systolic_blood_pressure']+1)

# %%
sns.displot(Maternal_df['systolic_blood_pressure'])

# %%
sns.displot(Maternal_df['diastolic_blood_pressure'])

# %%
import numpy as np

# %%
 Maternal_df["diastolic_blood_pressure"]**(1/2)
# Out:
# 0        8.637364
# 1        8.637364
# 2        8.637364
# 3        8.637364
# 4        8.637364
#            ...
# 25663    7.615773
# 25664    7.615773
# 25665    8.366600
# 25666    8.366600
# 25667    8.000000
# Name: diastolic_blood_pressure, Length: 25668, dtype: float64

# %%
sns.displot(Maternal_df['diastolic_blood_pressure'])

# %%
sns.displot(Maternal_df['test_result'])

# %% [markdown]
# # UNIVARIATE OBSERVATIONS.

# %% [markdown]
# 1. A total of 25668 observations of both male and female patients were made at the health facility, of which 25000 were pregnant women, 97.3% survived the materanl deaths after derlivery at the health facilities.
# 2. Out of 25668 total  observations only 668 were male while 25000 were women.
# 3. The eastern province had the highest number of patients at the health facility,with about more than 20000 followed by lusaka,southern ,luapula while the lowest number of patients was in copperbelt.
# 4. The delivery discharge service had a count of 25000 patients country wide, of which were women.
# 5.  New born pmtct dosage was given to 350 sigle dose and double to about 300, bringing the total to about 650 pmtct    doses.
# 6. Doses had  count of 100 as the highest that recieved doses ,followed by about 60 and the rest below 20.
# 7. A total of 700 patients were screened for tb while a total count of 3500 patients were not screened for tb.
# 8. 3500 new borns recieved the Polio opv while only less than a 100 recieved Dpt and the rest of the umminazations   were not recieved.
# 9. A total of 3500 scored un applicable on baby recieving ARVs within 72 hours,while 900 babies did not recieve the ARVs however a low score of those that recieved ARVs for babies within 72 hours was 600.
# 10. A total of 3000 women did not have a uterus contraction, while only less than 100 had a uterus contraction during delivery.
# 11. Breast feeding method of feeding had a high count of 16000, while formular had a low count of 4000.
# 12. About 18000 mothers recieved breast feeding well for the new borns, while only about less than 2500 did not breast feed well.
# 13. About 18000  New borns were fed in one hour and only about 500 were not feed within an hour after delivery.
# 10. feeding options incl mixed  EBF has a count of 3000 while ERF and Mixed have none.
# 11. About 18000 under 5 cards were recieved by the mothers in total.
# 12. 5 new borns recieved the vitamin  A suppliment were as 30 did not recieve vitamin A suppliment, making it a 16.6% of the total vitamin A suppliment.
# 13.  A total number of 6000  new borns were enrolled for Bcg and only 1000 recieved it.making it a 16.6 % of the total number enrolled for bcg.
# 14. The pallor type enrolled about 3000 Nil and only Mild pallor type recorded 100, while the Moderate typye pallor recorded Zero.
# 15. The ctx_first_dose recoded a false and had a count of 3.0.
# 16. About 25000 observations were made on temperature and fail in the normal range of 36 to 37 degrees with a few higher exceptions.
# 17. 25000 observations were made on systolic blood pressure and the results show that systolic blood pressure scored
# 18. Diastolic blood pressure had a count of 25000 observations and most high results were recorded between 8ommHg and 75 mmHg ,which normal for diastolic blood pressure on pregnant women , though they were also some outliers in the measurements.
# 19. Looks like temperature was normal for most pregnant women around 36.9 and did not have outliers.

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(9,9))
sns.heatmap(Maternal_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.barplot(data=Maternal_df ,x='systolic_blood_pressure', y='province')
# Out:
# <AxesSubplot:xlabel='systolic_blood_pressure', ylabel='province'>

# %%
sns.displot(data=Maternal_df ,x='sex', y='ctx_first_dose')

# %%
sns.histplot(data=Maternal_df ,x='sex', y='province')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='province'>

# %%
sns.histplot(data=Maternal_df ,x='service', y='province')
# Out:
# <AxesSubplot:xlabel='service', ylabel='province'>

# %%
sns.barplot(data=Maternal_df ,x='uterus_contracted',y = 'service')
# Out:
# <AxesSubplot:xlabel='uterus_contracted', ylabel='service'>

# %%
plt.figure(figsize=(7,6))
sns.barplot(data=Maternal_df, x='province',y='maternal_death_after_delivery')
# Out:
# <AxesSubplot:xlabel='province', ylabel='maternal_death_after_delivery'>

# %%
sns.barplot(data=Maternal_df ,x='sex', y='screened_for_tb')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='screened_for_tb'>

# %%
sns.barplot(data=Maternal_df,x='province' ,y='screened_for_tb')
# Out:
# <AxesSubplot:xlabel='province', ylabel='screened_for_tb'>

# %%
sns.histplot(data=Maternal_df, x="sex", y="art_number")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='art_number'>

# %%
sns.barplot(data=Maternal_df, x="maternal_death_after_delivery", y="diastolic_blood_pressure")
# Out:
# <AxesSubplot:xlabel='maternal_death_after_delivery', ylabel='diastolic_blood_pressure'>

# %%
sns.barplot(data=Maternal_df, x="maternal_death_after_delivery",y= "temperature")
# Out:
# <AxesSubplot:xlabel='maternal_death_after_delivery', ylabel='temperature'>

# %%
sns.barplot(data=Maternal_df ,x="pallor",y ='maternal_death_after_delivery')
# Out:
# <AxesSubplot:xlabel='pallor', ylabel='maternal_death_after_delivery'>

# %%
sns.barplot(data=Maternal_df ,x='pallor_type',y ='maternal_death_after_delivery')
# Out:
# <AxesSubplot:xlabel='pallor_type', ylabel='maternal_death_after_delivery'>

# %%
sns.barplot(data=Maternal_df, x="lochia", y="maternal_death_after_delivery")
# Out:
# <AxesSubplot:xlabel='lochia', ylabel='maternal_death_after_delivery'>

# %%
sns.histplot(data=Maternal_df, x='province',y='child_number')
# Out:
# <AxesSubplot:xlabel='province', ylabel='child_number'>

# %%
plt.figure(figsize=(8,9))
sns.histplot(data=Maternal_df, x="province", y= "lochia")
# Out:
# <AxesSubplot:xlabel='province', ylabel='lochia'>

# %%
sns.histplot(data=Maternal_df, x='baby_received_arv_within_72_hours',y='province')
# Out:
# <AxesSubplot:xlabel='baby_received_arv_within_72_hours', ylabel='province'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=Maternal_df ,x='feeding_methods', y= 'province')
# Out:
# <AxesSubplot:xlabel='feeding_methods', ylabel='province'>

# %%
sns.histplot(data=Maternal_df ,x='feeding_options_incl_mixed', y= 'province')
# Out:
# <AxesSubplot:xlabel='feeding_options_incl_mixed', ylabel='province'>

# %%
sns.histplot(data=Maternal_df ,x='feeding_options_incl_mixed', y= 'service')
# Out:
# <AxesSubplot:xlabel='feeding_options_incl_mixed', ylabel='service'>

# %%
sns.barplot(data=Maternal_df ,x='under5_card_given', y= 'province')
# Out:
# <AxesSubplot:xlabel='under5_card_given', ylabel='province'>

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=Maternal_df ,x='province', y='vitamin_a_supplement')
# Out:
# <AxesSubplot:xlabel='province', ylabel='vitamin_a_supplement'>

# %% [markdown]
# # BIVARIATE OBSERVATIONS.

# %% [markdown]
# 1. The heat map shows the level of correaltions with all variables in the study.
# 2. Systolic blood presure was highest in nothern province at about 130,followed by eastern province with above 125 this shows risks of stage 1 hypertention.while the rest of the provinces were normal systolic blood presure between 100 to 120.however Western province had the lowest with about 110.
# 3. Eastern province and Luapula province had a high number of male and female patients at health centers ,while the rest of the provinces had more females and almost very few male patients at the health centers.
# 4. Eastern province had the highest service delivery discharge as compared to the rest of the provinces.
# 5. Uterus contraction were highest at about 0.0150 and caused delivery discharge With some exceptional cases or outliers going as far as 0.0175.
# 5. Central province had the highest maternal deaths after delivery with about 0.006 followed by eastern province with about 0.002 and the rest of the provinces did not record any maternal deaths after delivery.
# 6. The patients that enrolled for tb screen test 700 for male and 300 for women.This shows that they are more males went for tb screening as compared to women.
# 7. Tb screening recorded the highest in Luapula province with about 0.7, seconded by northern province with 0.3 ,while southern, western and eastern scored 0.2 and the lowest score was in Lusaka with a score of  0.5 .
# 8. Art numbers have been assigned to all female patients at the health centers.
# 9. The diastolic blood pressure for patients at the health facilities was at 80 mmHg, which is a normal reading when the heart is at rest, and recoded true and false maternal death after delivery ,the results show that were some deaths after delivery caused by diastolic blood pressure.
# 10. The temperature reading was at 40 degrees celcus which is higher than normal,at can be likened to postpurm fever which is between 37.8 to 38 degrees celcus.however the recoded true on deaths after delivery,which implies that temperatures caused some maternal deaths after delivery.
# 11. Pallor recoded false on maternal death after derlivery.This implies that they were no deaths after delivery caused by pollar.
# 12. Lochia Rubia is the only skin disease that had about 0.005 on maternal death delivery. while Alba and Serosa did not record any maternal death after derlivery.
# 13. Lochia rubia was recorded highest in eastern province seconded by seroca and Alba,while central province only recoded Rubia.The rest of the provinces did not recode any lochia.
# 14. Eastern province had the highest number of new borns that recieved ARVs within 72 hours,while most of the enrolled number of newborns on ARVs within 72 hours was non applicable in most provinces.
# 15. All the provinces recieved breastfeeding methods and formular feeding methods , with the highest being in eastern province followed by southern and lusaka that recieved breast feeding methods but not formular feeding methods.While copperbelt and northern province only recieved breast feeding methods and not formular.central and luapula province both recieved breast feeding methods only and not formular feeding methods.
# 16. feeding_options_incl_mixed was highest with EBF in Eastern province, seconded by Southern and Central province that recorded the same on EBF feeding options.While Lusaka,Copperbelt,Western,Northern and Luapula also recoded equal on the EBF feeding options.Eastern province also provided ERF  but did not provide mixed feeding options.Southern province also provided both ERF and Mixed feeding options,while the rest of the provinces only provided EBF for the feeding purposes.
# 17. Service delivery discharge was highest on EBF feeding options as compared to ERF and Mixed methods.
# 18. Copperbelt recieved the highest number of under 5 cards about 0.5 recieved with a few exceptional cases, seconded by Lusaka with 0.3, while Southern and western provinces recieved about 0.2 and Luapula with 1.0 while eastern province recieved the least under 5 cards with 0.5  and central province with 0.05 of the total under 5 cards given out.
# 19. Luapula province recieved the highest number for vitamin A suppliment with about 0.1, seconded by Lusaka province while copperbelt,Northern,Southern,Central,Eastern and western recorded 0 on vitamin  A suppliments.

# %% [markdown]
# # MULTIVARIATE  ANALYSIS

# %%
sns.scatterplot(data=Maternal_df, x="temperature",y="systolic_blood_pressure",hue="maternal_death_after_delivery")
# Out:
# <AxesSubplot:xlabel='temperature', ylabel='systolic_blood_pressure'>

# %%
sns.scatterplot(data=Maternal_df, x="temperature",y="diastolic_blood_pressure", hue="maternal_death_after_delivery")
# Out:
# <AxesSubplot:xlabel='temperature', ylabel='diastolic_blood_pressure'>

# %%
sns.scatterplot(data=Maternal_df, x="maternal_death_after_delivery",y="pulse_rate",hue = "province")
# Out:
# <AxesSubplot:xlabel='maternal_death_after_delivery', ylabel='pulse_rate'>

# %%
sns.scatterplot(data=Maternal_df, x= "diastolic_blood_pressure",y= "pulse_rate", hue="maternal_death_after_delivery")
# Out:
# <AxesSubplot:xlabel='diastolic_blood_pressure', ylabel='pulse_rate'>

# %%
sns.scatterplot(data=Maternal_df,x="systolic_blood_pressure",y="maternal_death_after_delivery",  hue="province")
# Out:
# <AxesSubplot:xlabel='systolic_blood_pressure', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="urine_glucose",y="maternal_death_after_delivery", hue="province")
# Out:
# <AxesSubplot:xlabel='urine_glucose', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="uterus_contracted",y="maternal_death_after_delivery",hue="province")
# Out:
# <AxesSubplot:xlabel='uterus_contracted', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="pallor_type",y="maternal_death_after_delivery",  hue="province")
# Out:
# <AxesSubplot:xlabel='pallor_type', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="lochia",y="maternal_death_after_delivery",  hue="province")
# Out:
# <AxesSubplot:xlabel='lochia', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="sex", y="other_immunizations",hue="province")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='other_immunizations'>

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=Maternal_df,x="feeding_methods",y="maternal_death_after_delivery",hue="province")
# Out:
# <AxesSubplot:xlabel='feeding_methods', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="sex",y="baby_received_arv_within_72_hours", hue="province")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='baby_received_arv_within_72_hours'>

# %%
sns.scatterplot(data=Maternal_df,x ="sex", y="under5_card_given",hue="province")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='under5_card_given'>

# %%
sns.scatterplot(data=Maternal_df,x="breast_fed_in_one_hour",y="service",hue="province")
# Out:
# <AxesSubplot:xlabel='breast_fed_in_one_hour', ylabel='service'>

# %%
sns.scatterplot(data=Maternal_df,x="vitamin_a_supplement",y="maternal_death_after_delivery",  hue="province")
# Out:
# <AxesSubplot:xlabel='vitamin_a_supplement', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="bcg_given",y="maternal_death_after_delivery", hue="province")
# Out:
# <AxesSubplot:xlabel='bcg_given', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="breastfeeding_well",y="maternal_death_after_delivery",  hue="province")
# Out:
# <AxesSubplot:xlabel='breastfeeding_well', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="feeding_options_incl_mixed",y="maternal_death_after_delivery",  hue="province")
# Out:
# <AxesSubplot:xlabel='feeding_options_incl_mixed', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="itn_used",y="maternal_death_after_delivery",hue="province")
# Out:
# <AxesSubplot:xlabel='itn_used', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x="ctx_first_dose", y="maternal_death_after_delivery",hue="province")
# Out:
# <AxesSubplot:xlabel='ctx_first_dose', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x='screened_for_tb',y="maternal_death_after_delivery",hue="province")
# Out:
# <AxesSubplot:xlabel='screened_for_tb', ylabel='maternal_death_after_delivery'>

# %%
sns.scatterplot(data=Maternal_df,x='ingredients',y="maternal_death_after_delivery",hue="province")
# Out:
# <AxesSubplot:xlabel='ingredients', ylabel='maternal_death_after_delivery'>

# %% [markdown]
# # OBSERVATIONS

# %% [markdown]
# 1. Pregnant women with very high systolic blood pressure were not at  high risk of maternal death after delivery.Despite having high tempatures of above 38 degrees celcus, they did not led to maternal death after delivery.
# 2. Most of the diastolic blood pressure score was between 80 to 120 mmHg which is normal,though in some cases it scored  as high as 125 to 175 mmHg however this did not cause any maternal deaths after delivery.And the temperature reading was as high as 38 degrees celcuis but did not cause any change onto the diastolic blood pressure.
# 3.  Central province recoded a pulse rate of 1000 and also maternal deaths after delivery. The results show maternal death after delivery associated with high pulse rate.
# 4. Central province scored high on pulse rate with 1000 and also recoded maternal deaths after delivery, while western,eastern province recoded no deaths after delivery and scored normal pulse rate.
# 5. Low systolic blood pressure 20mm Hg was recoreded from Western ,southern  and  while eastern recorded above 120 mmHg high on systolic blood blood pressure ,though this did not led to maternal deaths after delivery. Central province recorded low systolic blood pressure below 20 mmHg and also recoded cases of maternal deaths after delivery The results show a correlation between systolic blood pressure and maternal deaths after delivery.
# 6. Southern province had a negative result on urine glucose, while Eastern province recoded positive on urine glucose but both provonces  recoded 0.0 on maternal deaths after delivery.
# 7. uterus contractions were recorded in Southern province with a score of 0.0, while in luaska uterus contractions were recorded at 0.1 ,however this did not cause maternal deaths after delivery for both lusaka and southern province.Central province recoded between 0.1 and 0.2 uterus contraction and recoded 1.0 on maternal deaths after delivery.The results show that uterus contractions had caused some maternal deaths after delivery in central province.
# 8. Pollar type was recoded in Southern province with both Nil and mild type of pollar type,while eastern province scored Moderate on pollar type but both southern and eastern province  did not recode any maternal deaths on delivery.However Central province scored Nil on pollar type and recoded maternal deaths after delivery associated to Nil pollar type.
# 9.  Lochia was recorded with both Alba and Serosa lochia in southern province but had a low score of 0.0 on maternal deaths after delivery while eastern province recoded Rubra lochia and low maternal death after delivery of about 0.0. Central province  recoded lochia Rubra and scored high on maternal deaths after delivery.the results show maternal deaths after delivry that are associated with lochia rubra.
# 10. Other immunisations such as Tetanus were recieved by females in western province and not males,while eastern province females recievd meningitis,antirabies,haemphilus,measles,Dpt, and polio was given to both males and females in eastern province.
# 11. Breastfeeding services were recieved in western and southern province, while both breastfeeding and formular feeding methods were recieved in Central province. Both Central province and eastern province recoded maternal deaths after delivery in association to feeding methods recieved in the provinces.
# 12. copperbelt province scored yes on females that recieved  ARVs for babies within 72 hours. While eastern province scored not applicable for New born aRVs within 72 hours ,for both males and females.
# 13. Southern province scored 0.0 on under 5 cards recieved for females that did not recieve under 5cards while,the score for those that recieved the under 5 cards was 0.1. Eastern province scored 0.1 on males that recieved the under 5 cards.
# 14. Both Lusaka and Southern province recorded positive on service (delivery discharge) ,though luaska scored 0.0 or no score on breast fed in one hour.However Southern province scored a positive 1.0 on breast fed in one hour.
# 15. Southern province scored 0.0 or no score on Vitamin A suppliment ,while Luapula province scored 0.1 and positive on vitamin A suppliment.However both Luapula and southern province scored 0.0 on maternal death after delivery. The results show that both provinces did not recode any deaths after delivery in relation to Vitamin A suppliment.
# 16. Southern province recieved BCG and had a score of 1.0, though did not score any maternal deaths after delivery, while eastern province did not recieve BCG and had a score of 0.0 but also had a score of 1.0 ,that recorded maternal deaths after delivery.
# 17. Copperbelt recieved a score of 0.0 on breast feeding well and no maternal deaths after delivery, while Southern province also scored 1.0 and positive on breastfeeding well but no maternal deaths on delivery.However Central province scored 1.0 on breastfeeding and also 1.0 on maternal deaths after delivery ,showing that they were maternal deaths after delivery with a score of 1.0 in Central province.
# 18. EBF and mixed feeding options were recorded in southern province at a score of 0.0 but no maternal deaths after delivery were recoded.Eastern province aslo score on ERF feeding optionsand a 0.0 on maternal deaths after delivery.EBF feeding options were recorded in central province and 1.0 on maternal deaths after delivery,the results show that there was maternal deaths after delivery in central province that recieved EBF feeding options.
# 19. There were no deaths after delivery recorded in eastern province but there was both a score of 0.0,and 0.1 score on itn used.This shows that eastern province had both patients that recieved itn used and those that did not recieve it.
# 20. The copperbelt province recieved ctx_first_dose  but did not record any deaths after delivery.

# %% [markdown]
# ## FEATURE ENGINEERING

# %% [markdown]
# # Dropping columns.

# %%
Maternal_df.drop(columns=['client_id'],axis=1,inplace=True)
Maternal_df.drop(columns=['interaction_date','in_patient_register_number','in_patient_register_number','delivery_discharge_new_born_details_uuid'],axis=1,inplace=True)
